# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %% [markdown]
# https://www.kaggle.com/code/meenaaa/cancer-death-rate-xgboost/notebook

# %%
# data wrangling tools
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# statistical analysis
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# scikit-learn
from sklearn.model_selection import train_test_split

import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
trainset = pd.read_csv("G:/My Drive/DataMining/POC/LungCancer/Dataset/Transform/trainset.csv", index_col = 0)
trainset.head(5)
# Out:
#                                avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Greene County, North Carolina     0.083439          0.122371       0.291870
# McHenry County, Illinois          1.000000          1.000000       1.000000
# Wichita County, Kansas            1.000000          0.009178       0.614898
# Mineral County, Montana           0.024442          0.027533       0.275623
# Ohio County, West Virginia        0.254530          0.367113       0.350392
#
#                                medIncome  popEst2015  povertyPercent  \
# Geography
# Greene County, North Carolina   0.133236    0.846543             0.0
# McHenry County, Illinois        1.000000    0.124789             0.0
# Wichita County, Kansas          0.008714    0.279933             0.0
# Mineral County, Montana         0.022454    0.475548             0.0
# Ohio County, West Virginia      0.277148    0.512648             1.0
#
#                                studyPerCap  binnedInc  MedianAge  \
# Geography
# Greene County, North Carolina       0.5344          0   0.494915
# McHenry County, Illinois            0.5440          8   0.535593
# Wichita County, Kansas              0.4288          6   0.410169
# Mineral County, Montana             1.0000          0   1.000000
# Ohio County, West Virginia          0.6720          1   0.640678
#
#                                MedianAgeMale  ...  PctBlack  PctAsian  \
# Geography                                     ...
# Greene County, North Carolina       0.592934  ...  0.055978  1.000000
# McHenry County, Illinois            0.549923  ...  0.982636  0.522842
# Wichita County, Kansas              0.559140  ...  0.118496  0.574822
# Mineral County, Montana             0.872504  ...  0.061625  0.028026
# Ohio County, West Virginia          0.700461  ...  0.317203  0.057158
#
#                                PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Greene County, North Carolina      0.478172              0.891040   0.407456
# McHenry County, Illinois           0.886624              0.457204   0.401518
# Wichita County, Kansas             0.788191              0.753252   0.388981
# Mineral County, Montana            0.543234              0.355567   0.425932
# Ohio County, West Virginia         0.455453              0.347449   0.411415
#
#                                City  State  Region  Division  TARGET_deathRate
# Geography
# Greene County, North Carolina   603     33       2         6          0.648195
# McHenry County, Illinois        948     13       0         0          0.739132
# Wichita County, Kansas         1614     16       0         7          0.682701
# Mineral County, Montana         984     26       3         3          0.913427
# Ohio County, West Virginia     1085     48       2         6          0.810853
#
# [5 rows x 37 columns]

# %%
valset = pd.read_csv("G:/My Drive/DataMining/POC/LungCancer/Dataset/Transform/valset.csv", index_col = 0)
valset.head(5)
# Out:
#                               avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Linn County, Oregon              0.563843          0.826004       0.433484
# Champaign County, Illinois       0.653182          0.807648       0.505499
# Saratoga County, New York        0.933418          1.073805       0.982915
# Montmorency County, Michigan     0.069111          0.104015       0.305802
# Barrow County, Georgia           0.231774          0.339579       0.540069
#
#                               medIncome  popEst2015  povertyPercent  \
# Geography
# Linn County, Oregon            0.785557    0.536256        0.039546
# Champaign County, Illinois     1.108948    0.654300        0.961857
# Saratoga County, New York      1.108948    0.134907        0.126423
# Montmorency County, Michigan   0.055315    0.421585        0.000000
# Barrow County, Georgia         0.489118    0.330523        0.000000
#
#                               studyPerCap  binnedInc  MedianAge  \
# Geography
# Linn County, Oregon                0.5504          3   0.555932
# Champaign County, Illinois         0.2240          4   0.196610
# Saratoga County, New York          0.6240          8   0.627119
# Montmorency County, Michigan       0.9616          1   0.959322
# Barrow County, Georgia             0.4000          5   0.355932
#
#                               MedianAgeMale  ...  PctBlack  PctAsian  \
# Geography                                    ...
# Linn County, Oregon                0.556068  ...  0.456603  0.244924
# Champaign County, Illinois         0.258065  ...  0.980500  0.193658
# Saratoga County, New York          0.632873  ...  0.885327  0.077846
# Montmorency County, Michigan       0.987711  ...  0.000000  0.067381
# Barrow County, Georgia             0.427035  ...  0.980500  0.391169
#
#                               PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Linn County, Oregon               0.658341              0.496995   0.418344
# Champaign County, Illinois        0.382380              0.369846   0.306170
# Saratoga County, New York         0.680359              0.482247   0.377763
# Montmorency County, Michigan      0.599090              0.348074   0.487958
# Barrow County, Georgia            0.735752              0.567292   0.436490
#
#                               TARGET_deathRate  City  State  Region  Division
# Geography
# Linn County, Oregon                   0.747251   139     32       3         5
# Champaign County, Illinois            0.673636    40      8       0         0
# Saratoga County, New York             0.831963   228     27       1         2
# Montmorency County, Michigan          0.766196   172     17       0         0
# Barrow County, Georgia                0.693934     8      6       2         6
#
# [5 rows x 37 columns]

# %%
trainset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2467 entries, Greene County, North Carolina to Van Wert County, Ohio
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              2467 non-null   float64
#  1   avgDeathsPerYear         2467 non-null   float64
#  2   incidenceRate            2467 non-null   float64
#  3   medIncome                2467 non-null   float64
#  4   popEst2015               2467 non-null   float64
#  5   povertyPercent           2467 non-null   float64
#  6   studyPerCap              2467 non-null   float64
#  7   binnedInc                2467 non-null   int64
#  8   MedianAge                2467 non-null   float64
#  9   MedianAgeMale            2467 non-null   float64
#  10  MedianAgeFemale          2467 non-null   float64
#  11  AvgHouseholdSize         2467 non-null   float64
#  12  PercentMarried           2467 non-null   float64
#  13  PctNoHS18_24             2467 non-null   float64
#  14  PctHS18_24               2467 non-null   float64
#  15  PctSomeCol18_24          2467 non-null   float64
#  16  PctBachDeg18_24          2467 non-null   float64
#  17  PctHS25_Over             2467 non-null   float64
#  18  PctBachDeg25_Over        2467 non-null   float64
#  19  PctEmployed16_Over       2467 non-null   float64
#  20  PctUnemployed16_Over     2467 non-null   float64
#  21  PctPrivateCoverage       2467 non-null   float64
#  22  PctPrivateCoverageAlone  2467 non-null   float64
#  23  PctEmpPrivCoverage       2467 non-null   float64
#  24  PctPublicCoverage        2467 non-null   float64
#  25  PctPublicCoverageAlone   2467 non-null   float64
#  26  PctWhite                 2467 non-null   float64
#  27  PctBlack                 2467 non-null   float64
#  28  PctAsian                 2467 non-null   float64
#  29  PctOtherRace             2467 non-null   float64
#  30  PctMarriedHouseholds     2467 non-null   float64
#  31  BirthRate                2467 non-null   float64
#  32  City                     2467 non-null   int64
#  33  State                    2467 non-null   int64
#  34  Region                   2467 non-null   int64
#  35  Division                 2467 non-null   int64
#  36  TARGET_deathRate         2467 non-null   float64
# dtypes: float64(32), int64(5)
# memory usage: 732.4+ KB

# %%
valset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305 entries, Linn County, Oregon to Macon County, Missouri
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              305 non-null    float64
#  1   avgDeathsPerYear         305 non-null    float64
#  2   incidenceRate            305 non-null    float64
#  3   medIncome                305 non-null    float64
#  4   popEst2015               305 non-null    float64
#  5   povertyPercent           305 non-null    float64
#  6   studyPerCap              305 non-null    float64
#  7   binnedInc                305 non-null    int64
#  8   MedianAge                305 non-null    float64
#  9   MedianAgeMale            305 non-null    float64
#  10  MedianAgeFemale          305 non-null    float64
#  11  AvgHouseholdSize         305 non-null    float64
#  12  PercentMarried           305 non-null    float64
#  13  PctNoHS18_24             305 non-null    float64
#  14  PctHS18_24               305 non-null    float64
#  15  PctSomeCol18_24          305 non-null    float64
#  16  PctBachDeg18_24          305 non-null    float64
#  17  PctHS25_Over             305 non-null    float64
#  18  PctBachDeg25_Over        305 non-null    float64
#  19  PctEmployed16_Over       305 non-null    float64
#  20  PctUnemployed16_Over     305 non-null    float64
#  21  PctPrivateCoverage       305 non-null    float64
#  22  PctPrivateCoverageAlone  305 non-null    float64
#  23  PctEmpPrivCoverage       305 non-null    float64
#  24  PctPublicCoverage        305 non-null    float64
#  25  PctPublicCoverageAlone   305 non-null    float64
#  26  PctWhite                 305 non-null    float64
#  27  PctBlack                 305 non-null    float64
#  28  PctAsian                 305 non-null    float64
#  29  PctOtherRace             305 non-null    float64
#  30  PctMarriedHouseholds     305 non-null    float64
#  31  BirthRate                305 non-null    float64
#  32  TARGET_deathRate         305 non-null    float64
#  33  City                     305 non-null    int64
#  34  State                    305 non-null    int64
#  35  Region                   305 non-null    int64
#  36  Division                 305 non-null    int64
# dtypes: float64(32), int64(5)
# memory usage: 90.5+ KB

# %%
X_train = trainset.drop(['TARGET_deathRate'], axis = 1)
y_train = trainset['TARGET_deathRate']

# %%
X_val = valset.drop(['TARGET_deathRate'], axis = 1)
y_val = valset['TARGET_deathRate']

# %%
import joblib
scaler_single_filename = "G:/My Drive/DataMining/POC/LungCancer/local/Model/Scaler/scaler_single.save"
scaler_single = joblib.load(scaler_single_filename)

# %% [markdown]
# # Measure

# %%
#evaluation metrics for regression model
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error, r2_score

# %%
def deviation_function(y_val, pred):
  deviation = []
  for i in range(0, len(y_val)):
    deviation.append(abs(pred[i] - y_val[i]) / y_val[i])
  return np.array(deviation).mean()

# %% [markdown]
# # Linear Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
#linear regression model
from sklearn.linear_model import LinearRegression 
#Grid search model
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'fit_intercept':[True,False], 
    'copy_X':[True, False]
    }

# %%
lr = LinearRegression()

# %%
#training the model
lr_model_grid = GridSearchCV(lr,parameters, scoring='r2', cv=None).fit(X_train, y_train)

# %%
lr_pred = lr_model_grid.predict(X_val)

# %% [markdown]
# ## Evaluate

# %%
y_val_inv = scaler_single.inverse_transform(np.array(y_val).reshape(1, -1))
lr_pred_inv = scaler_single.inverse_transform(np.array(lr_pred).reshape(1, -1))

# %%
#evaluating the model with the following metrics
#mean squared error
lr_mse=mean_squared_error(lr_pred_inv[0], y_val_inv[0])     
#mean absolute error     
lr_mae=mean_absolute_error(lr_pred_inv[0], y_val_inv[0])  
#root mean squared error      
lr_rmse=np.sqrt(mean_squared_error(lr_pred_inv[0], y_val_inv[0]))
#r2 score
lr_r2 = r2_score(lr_pred_inv[0], y_val_inv[0])
print(f'mse: {lr_mse}')
print(f'mae: {lr_mae}')
print(f'rmse: {lr_rmse}')
print(f"R-Squared: {lr_r2}")
# Out:
# mse: 1189.3503691067626
# mae: 26.304923216840084
# rmse: 34.486959406517165
# R-Squared: -0.868686565778428

# %%
lr_df =pd.DataFrame({"mse": lr_mse,"mae": lr_mae,"rmse": lr_rmse, "r2": lr_r2, "deviation": deviation_function(lr_pred_inv[0], y_val_inv[0])},index=['Linear Regression'])

# %%
Axis = [y_val_inv[0].mean()] * len(y_val_inv[0])
plt.figure(figsize=(16, 9))
plt.ylabel('Linear Regression Result')
plt.plot(y_val_inv[0], 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(lr_pred_inv[0], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Support Vector Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html

# %%
#support vector regression model
from sklearn.svm import SVR
#Grid search model
from sklearn.model_selection import GridSearchCV

# %%
svr = SVR()

# %%
parameters = {
    'kernel':['sigmoid', 'rbf', 'poly', 'linear'], 
    'C': np.arange(0.1, 1, 0.1),
    'gamma': ['auto', 'scale'],
    'degree': np.arange(1, 10, 1)
    }

# %%
#training the model
svr_model_grid = GridSearchCV(svr,parameters, scoring='r2', cv=None).fit(X_train, y_train)

# %%
svr_pred = svr_model_grid.predict(X_val)

# %% [markdown]
# ## Evaluate

# %%
y_val_inv = scaler_single.inverse_transform(np.array(y_val).reshape(1, -1))
svr_pred_inv = scaler_single.inverse_transform(np.array(svr_pred).reshape(1, -1))

# %%
#evaluating the model with the following metrics
#mean squared error
svr_mse=mean_squared_error(svr_pred_inv[0], y_val_inv[0])     
#mean absolute error     
svr_mae=mean_absolute_error(svr_pred_inv[0], y_val_inv[0])  
#root mean squared error      
svr_rmse=np.sqrt(mean_squared_error(svr_pred_inv[0], y_val_inv[0]))
#r2 score
svr_r2 = r2_score(svr_pred_inv[0], y_val_inv[0])
print(f'mse: {svr_mse}')
print(f'mae: {svr_mae}')
print(f'rmse: {svr_rmse}')
print(f"R-Squared: {svr_r2}")
# Out:
# mse: 0.0038957214546577615
# mae: 0.048234783019526474
# rmse: 0.06241571480530974
# R-Squared: 0.16139820058409993

# %%
svr_df =pd.DataFrame({"mse": svr_mse,"mae": svr_mae,"rmse": svr_rmse, "r2": svr_r2, "deviation": deviation_function(y_val_inv[0], svr_pred_inv[0])},index=['Support Vector Regression'])

# %%
Axis = [y_val_inv[0].mean()] * len(y_val_inv[0])
plt.figure(figsize=(16, 9))
plt.ylabel('Support Vector Regression Result')
plt.plot(y_val_inv[0], 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(svr_pred_inv[0], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html

# %%
# decision tree regression model
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()

# %%
parameters = {
    'criterion': ["squared_error", "friedman_mse", "absolute_error", "poisson"], 
    'splitter': ["best", "random"], 
    'max_features': ["auto", "sqrt", "log2", None]
    }

# %%
#training the model
dtr_model_grid = GridSearchCV(dtr,parameters, scoring='r2', cv=None).fit(X_train, y_train)

# %%
dtr_pred = dtr_model_grid.predict(X_val)

# %% [markdown]
# ## Evaluate

# %%
y_val_inv = scaler_single.inverse_transform(np.array(y_val).reshape(1, -1))
dtr_pred_inv = scaler_single.inverse_transform(np.array(dtr_pred).reshape(1, -1))

# %%
#evaluating the model with the following metrics
#mean squared error
dtr_mse=mean_squared_error(dtr_pred_inv[0], y_val_inv[0])     
#mean absolute error     
dtr_mae=mean_absolute_error(dtr_pred_inv[0], y_val_inv[0])  
#root mean squared error      
dtr_rmse=np.sqrt(mean_squared_error(dtr_pred_inv[0], y_val_inv[0]))
#r2 score
dtr_r2 = r2_score(dtr_pred_inv[0], y_val_inv[0])
print(f'mse: {dtr_mse}')
print(f'mae: {dtr_mae}')
print(f'rmse: {dtr_rmse}')
print(f"R-Squared: {dtr_r2}")
# Out:
# mse: 0.0070129935634488634
# mae: 0.06475599136788703
# rmse: 0.08374361804608674
# r2_score: 0.15790776651528715

# %%
dtr_df =pd.DataFrame({"mse": dtr_mse,"mae": dtr_mae,"rmse": dtr_rmse, "r2": dtr_r2, "deviation": deviation_function(y_val_inv[0], dtr_pred_inv[0])},index=['Decision Tree Regression'])

# %%
Axis = [y_val_inv[0].mean()] * len(y_val_inv[0])
plt.figure(figsize=(16, 9))
plt.ylabel('Decision Tree Regression Result')
plt.plot(y_val_inv[0], 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(dtr_pred_inv[0], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html

# %%
# random forest regression model
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
parameters = {
    'criterion': ["squared_error", "absolute_error", "friedman_mse", "poisson"], 
    'max_features': [1, "sqrt", "log2", None]
    }

# %%
#training the model
rfr_model_grid = GridSearchCV(rfr,parameters, scoring='r2', cv=None).fit(X_train, y_train)

# %%
rfr_pred = rfr_model_grid.predict(X_val)

# %% [markdown]
# ## Evaluate

# %%
y_val_inv = scaler_single.inverse_transform(np.array(y_val).reshape(1, -1))
rfr_pred_inv = scaler_single.inverse_transform(np.array(rfr_pred).reshape(1, -1))

# %%
#evaluating the model with the following metrics
#mean squared error
rfr_mse=mean_squared_error(rfr_pred_inv[0], y_val_inv[0])     
#mean absolute error     
rfr_mae=mean_absolute_error(rfr_pred_inv[0], y_val_inv[0])  
#root mean squared error      
rfr_rmse=np.sqrt(mean_squared_error(rfr_pred_inv[0], y_val_inv[0]))
#r2 score
rfr_r2 = r2_score(rfr_pred_inv[0], y_val_inv[0])
print(f'mse: {rfr_mse}')
print(f'mae: {rfr_mae}')
print(f'rmse: {rfr_rmse}')
print(f"R-Squared: {rfr_r2}")
# Out:
# mse: 0.003432491793210964
# mae: 0.04396805685512005
# rmse: 0.058587471298998425
# r2_score: 0.26095505478496783

# %%
rfr_df =pd.DataFrame({"mse": rfr_mse,"mae": rfr_mae,"rmse": rfr_rmse, "r2": rfr_r2, "deviation": deviation_function(rfr_pred_inv[0], y_val_inv[0])},index=['Random Forest Regression'])

# %%
Axis = [y_val_inv[0].mean()] * len(y_val_inv[0])
plt.figure(figsize=(16, 9))
plt.ylabel('Random Forest Regression Result')
plt.plot(y_val_inv[0], 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(rfr_pred_inv[0], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # XGBoost Regression

# %% [markdown]
# https://stackabuse.com/bytes/end-to-end-xgboost-regression-pipeline-with-scikit-learn/

# %%
# xgboost model
from xgboost import XGBRegressor

# %%
xgbr = XGBRegressor()

# %%
parameters = {
    'n_estimators': [80, 90, 100, 125, 150,200,1000,2000,3000, 3500],
    'max_depth': [2,3,4,5,8,16,None],
    'learning_rate': np.arange(0.1, 1, 0.1)
}

# %%
#training the model
xgbr_model_grid = GridSearchCV(xgbr,parameters, scoring='r2', cv=None).fit(X_train, y_train)

# %%
xgbr_pred = xgbr_model_grid.predict(X_val)

# %% [markdown]
# ## Evaluate

# %%
y_val_inv = scaler_single.inverse_transform(np.array(y_val).reshape(1, -1))
xgbr_pred_inv = scaler_single.inverse_transform(np.array(xgbr_pred).reshape(1, -1))

# %%
#evaluating the model with the following metrics
#mean squared error
xgbr_mse=mean_squared_error(xgbr_pred_inv[0], y_val_inv[0])     
#mean absolute error     
xgbr_mae=mean_absolute_error(xgbr_pred_inv[0], y_val_inv[0])  
#root mean squared error      
xgbr_rmse=np.sqrt(mean_squared_error(xgbr_pred_inv[0], y_val_inv[0]))
#r2 score
xgbr_r2 = r2_score(xgbr_pred_inv[0], y_val_inv[0])
print(f'mse: {xgbr_mse}')
print(f'mae: {xgbr_mae}')
print(f'rmse: {xgbr_rmse}')
print(f"R-Squared: {xgbr_r2}")
# Out:
# mse: 0.0018190479851633318
# mae: 0.032323165307948105
# rmse: 0.042650298769918736
# r2_score: 0.714333569184878

# %%
xgbr_df =pd.DataFrame({"mse": xgbr_mse,"mae": xgbr_mae,"rmse": xgbr_rmse,  "r2": xgbr_r2, "deviation": deviation_function(xgbr_pred_inv[0], y_val_inv[0])},index=['XGBoost Regression'])

# %%
Axis = [y_val_inv[0].mean()] * len(y_val_inv[0])
plt.figure(figsize=(16, 9))
plt.ylabel('XGBoost Regression Result')
plt.plot(y_val_inv[0], 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(xgbr_pred_inv[0], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Comparision

# %% [markdown]
# https://stats.stackexchange.com/questions/183265/what-does-negative-r-squared-mean#:~:text=It%20means%20you've%20done,least%20squares%20regression%20line%20itself.

# %% [markdown]
# https://www.kaggle.com/questions-and-answers/267943

# %%
df_evaluation = pd.concat([lr_df, svr_df, dtr_df, rfr_df, xgbr_df]) 
df_evaluation
# Out:
#                                 mse       mae      rmse        r2
# Linear Regression          0.003797  0.047375  0.061621  0.216903
# Support Vector Regression  0.003896  0.048235  0.062416  0.161398
# Decision Tree Regression   0.007013  0.064756  0.083744  0.157908
# Random Forest Regression   0.003432  0.043968  0.058587  0.260955
# XGBoost Regression         0.001819  0.032323  0.042650  0.714334

# %%
df_evaluation.to_csv("G:/My Drive/DataMining/POC/LungCancer/local/Evaluation/Transform/ogridsearch.csv")

# %% [markdown]
# # Save Model

# %%
import pickle
lr_filename = 'G:/My Drive/DataMining/POC/LungCancer/local/Model/Transform/lr_GridSearch.h5'
pickle.dump(lr_model_grid, open(lr_filename, 'wb'))
svr_filename = 'G:/My Drive/DataMining/POC/LungCancer/local/Model/Transform/svr_GridSearch.h5'
pickle.dump(svr_model_grid, open(svr_filename, 'wb'))
rfr_filename = 'G:/My Drive/DataMining/POC/LungCancer/local/Model/Transform/rfr_GridSearch.h5'
pickle.dump(rfr_model_grid, open(rfr_filename, 'wb'))
dtr_filename = 'G:/My Drive/DataMining/POC/LungCancer/local/Model/Transform/dtr_GridSearch.h5'
pickle.dump(dtr_model_grid, open(dtr_filename, 'wb'))
xgbr_filename = 'G:/My Drive/DataMining/POC/LungCancer/local/Model/Transform/xgbr_GridSearch.h5'
pickle.dump(xgbr_model_grid, open(xgbr_filename, 'wb'))

# %%
np.save(f"G:/My Drive/DataMining/POC/LungCancer/local/Parameter/Transform/lr_parameter_gridsearch.npy", lr_model_grid.best_params_)
np.save(f"G:/My Drive/DataMining/POC/LungCancer/local/Parameter/Transform/svr_parameter_gridsearch.npy", svr_model_grid.best_params_)
np.save(f"G:/My Drive/DataMining/POC/LungCancer/local/Parameter/Transform/xgbr_parameter_gridsearch.npy", xgbr_model_grid.best_params_)
np.save(f"G:/My Drive/DataMining/POC/LungCancer/local/Parameter/Transform/dtr_parameter_gridsearch.npy", dtr_model_grid.best_params_)
np.save(f"G:/My Drive/DataMining/POC/LungCancer/local/Parameter/Transform/rfr_parameter_gridsearch.npy", rfr_model_grid.best_params_)
