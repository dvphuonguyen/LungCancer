# %% [markdown]
# https://www.kaggle.com/code/meenaaa/cancer-death-rate-xgboost/notebook

# %% [markdown]
# https://www.researchgate.net/publication/341042405_On_linear_regression_models_with_hierarchical_categorical_variables

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data wrangling tools
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# statistical analysis
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# scikit-learn
from sklearn.model_selection import train_test_split

import time
import pickle

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Raw Dataset

# %%
trainset_raw = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Raw/trainset.csv", index_col = 0)
trainset_raw.head(5)
# Out:
#                                avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Greene County, North Carolina        105.0            43.000     440.800000
# McHenry County, Illinois            1192.5           329.875     474.400000
# Wichita County, Kansas              1192.5             6.000     453.549422
# Mineral County, Montana               35.0            12.000     538.800000
# Ohio County, West Virginia           308.0           123.000     500.900000
#
#                                medIncome  popEst2015  povertyPercent  \
# Geography
# Greene County, North Carolina      37263   21134.000            28.3
# McHenry County, Illinois           72741  153227.875             6.9
# Wichita County, Kansas             53447    2157.000            11.5
# Mineral County, Montana            36449    4251.000            17.3
# Ohio County, West Virginia         40195   43066.000            18.4
#
#                                studyPerCap  binnedInc  MedianAge  \
# Geography
# Greene County, North Carolina     0.000000          0      39.00
# McHenry County, Illinois          0.000000          8      39.30
# Wichita County, Kansas            0.000000          6      35.70
# Mineral County, Montana           0.000000          0      53.55
# Ohio County, West Virginia      209.768024          1      43.30
#
#                                MedianAgeMale  ...   PctBlack  PctAsian  \
# Geography                                     ...
# Greene County, North Carolina           37.0  ...  24.785427  0.150038
# McHenry County, Illinois                38.2  ...   1.345992  2.633745
# Wichita County, Kansas                  34.5  ...   0.000000  0.317604
# Mineral County, Montana                 51.9  ...   0.070788  0.165172
# Ohio County, West Virginia              41.3  ...   4.152439  0.850196
#
#                                PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Greene County, North Carolina      5.051674             43.921351   8.353222
# McHenry County, Illinois           2.641228             61.798687   4.286142
# Wichita County, Kansas             2.903811             57.490397   7.061503
# Mineral County, Montana            0.141576             46.769034   3.333333
# Ohio County, West Virginia         0.288746             42.926988   3.257227
#
#                                City  State  Region  Division  TARGET_deathRate
# Geography
# Greene County, North Carolina   603     33       2         6             183.2
# McHenry County, Illinois        948     13       0         0             181.4
# Wichita County, Kansas         1614     16       0         7             177.6
# Mineral County, Montana         984     26       3         3             188.8
# Ohio County, West Virginia     1085     48       2         6             184.4
#
# [5 rows x 37 columns]

# %%
valset_raw = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Raw/valset.csv", index_col = 0)
valset_raw.head(5)
# Out:
#                               avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Linn County, Oregon                 675.0               273          477.4
# Champaign County, Illinois          781.0               267          450.2
# Saratoga County, New York          1113.5               354          508.7
# Montmorency County, Michigan         88.0                37          484.4
# Barrow County, Georgia              281.0               114          457.7
#
#                               medIncome  popEst2015  povertyPercent  \
# Geography
# Linn County, Oregon               44358    120547.0            19.1
# Champaign County, Illinois        47966    169831.5            22.6
# Saratoga County, New York         71885    169831.5             7.2
# Montmorency County, Michigan      37961      9259.0            15.7
# Barrow County, Georgia            49698     75370.0            13.0
#
#                               studyPerCap  binnedInc  MedianAge  \
# Geography
# Linn County, Oregon              8.295520          3      39.50
# Champaign County, Illinois     201.766857          4      29.30
# Saratoga County, New York       26.519454          8      41.80
# Montmorency County, Michigan     0.000000          1      52.35
# Barrow County, Georgia           0.000000          5      34.80
#
#                               MedianAgeMale  ...   PctBlack  PctAsian  \
# Geography                                    ...
# Linn County, Oregon                    38.8  ...   0.437922  1.223828
# Champaign County, Illinois             28.2  ...  12.588086  2.628022
# Saratoga County, New York              40.9  ...   1.611447  2.372930
# Montmorency County, Michigan           50.7  ...   0.361664  0.000000
# Barrow County, Georgia                 32.9  ...  11.578626  2.628022
#
#                               PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Linn County, Oregon               1.237276             51.807095   4.659173
# Champaign County, Illinois        0.978296             39.728702   3.467191
# Saratoga County, New York         0.393254             52.770765   4.520914
# Montmorency County, Michigan      0.340389             49.213759   3.263086
# Barrow County, Georgia            1.976060             55.195246   5.318187
#
#                               TARGET_deathRate  City  State  Region  Division
# Geography
# Linn County, Oregon                      186.5   139     32       3         5
# Champaign County, Illinois               152.5    40      8       0         0
# Saratoga County, New York                174.2   228     27       1         2
# Montmorency County, Michigan             207.6   172     17       0         0
# Barrow County, Georgia                   192.0     8      6       2         6
#
# [5 rows x 37 columns]

# %%
testset_raw = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Raw/testset.csv", index_col = 0)
testset_raw.head(5)
# Out:
#                               avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Linn County, Oregon                 675.0               273          477.4
# Champaign County, Illinois          781.0               267          450.2
# Saratoga County, New York          1113.5               354          508.7
# Montmorency County, Michigan         88.0                37          484.4
# Barrow County, Georgia              281.0               114          457.7
#
#                               medIncome  popEst2015  povertyPercent  \
# Geography
# Linn County, Oregon               44358    120547.0            19.1
# Champaign County, Illinois        47966    169831.5            22.6
# Saratoga County, New York         71885    169831.5             7.2
# Montmorency County, Michigan      37961      9259.0            15.7
# Barrow County, Georgia            49698     75370.0            13.0
#
#                               studyPerCap  binnedInc  MedianAge  \
# Geography
# Linn County, Oregon              8.295520          3      39.50
# Champaign County, Illinois     201.766857          4      29.30
# Saratoga County, New York       26.519454          8      41.80
# Montmorency County, Michigan     0.000000          1      52.35
# Barrow County, Georgia           0.000000          5      34.80
#
#                               MedianAgeMale  ...   PctBlack  PctAsian  \
# Geography                                    ...
# Linn County, Oregon                    38.8  ...   0.437922  1.223828
# Champaign County, Illinois             28.2  ...  12.588086  2.628022
# Saratoga County, New York              40.9  ...   1.611447  2.372930
# Montmorency County, Michigan           50.7  ...   0.361664  0.000000
# Barrow County, Georgia                 32.9  ...  11.578626  2.628022
#
#                               PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Linn County, Oregon               1.237276             51.807095   4.659173
# Champaign County, Illinois        0.978296             39.728702   3.467191
# Saratoga County, New York         0.393254             52.770765   4.520914
# Montmorency County, Michigan      0.340389             49.213759   3.263086
# Barrow County, Georgia            1.976060             55.195246   5.318187
#
#                               TARGET_deathRate  City  State  Region  Division
# Geography
# Linn County, Oregon                      186.5   139     32       3         5
# Champaign County, Illinois               152.5    40      8       0         0
# Saratoga County, New York                174.2   228     27       1         2
# Montmorency County, Michigan             207.6   172     17       0         0
# Barrow County, Georgia                   192.0     8      6       2         6
#
# [5 rows x 37 columns]

# %%
X_train_raw = trainset_raw.drop(['TARGET_deathRate'], axis = 1)
y_train_raw = trainset_raw['TARGET_deathRate']

# %%
X_val_raw = valset_raw.drop(['TARGET_deathRate'], axis = 1)
y_val_raw = valset_raw['TARGET_deathRate']

# %%
X_test_raw = testset_raw.drop(['TARGET_deathRate'], axis = 1)
y_test_raw = testset_raw['TARGET_deathRate']

# %%
import pickle
rfe_filename_raw = '/content/drive/My Drive/DataMining/POC/LungCancer/FeatureSelection/Raw/raw_rfe.h5'
rfe_fit_raw = pickle.load(open(rfe_filename_raw, 'rb'))

# %%
X_train_rfe_raw = rfe_fit_raw.transform(X_train_raw)
X_val_rfe_raw = rfe_fit_raw.transform(X_val_raw)
X_test_rfe_raw = rfe_fit_raw.transform(X_test_raw)
print(X_train_rfe_raw.shape, y_train_raw.shape)
print(X_val_rfe_raw.shape, y_val_raw.shape)
print(X_test_rfe_raw.shape, y_test_raw.shape)
# Out:
# (2467, 18) (2467,)
# (305, 18) (305,)
# (305, 18) (305,)

# %% [markdown]
# # Min Max Dataset

# %%
trainset_minmax = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Transform/trainset.csv", index_col = 0)
trainset_minmax.head(5)
# Out:
#                                avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Greene County, North Carolina     0.083439          0.122371       0.291870
# McHenry County, Illinois          1.000000          1.000000       1.000000
# Wichita County, Kansas            1.000000          0.009178       0.614898
# Mineral County, Montana           0.024442          0.027533       0.275623
# Ohio County, West Virginia        0.254530          0.367113       0.350392
#
#                                medIncome  popEst2015  povertyPercent  \
# Geography
# Greene County, North Carolina   0.133236    0.846543             0.0
# McHenry County, Illinois        1.000000    0.124789             0.0
# Wichita County, Kansas          0.008714    0.279933             0.0
# Mineral County, Montana         0.022454    0.475548             0.0
# Ohio County, West Virginia      0.277148    0.512648             1.0
#
#                                studyPerCap  binnedInc  MedianAge  \
# Geography
# Greene County, North Carolina       0.5344          0   0.494915
# McHenry County, Illinois            0.5440          8   0.535593
# Wichita County, Kansas              0.4288          6   0.410169
# Mineral County, Montana             1.0000          0   1.000000
# Ohio County, West Virginia          0.6720          1   0.640678
#
#                                MedianAgeMale  ...  PctBlack  PctAsian  \
# Geography                                     ...
# Greene County, North Carolina       0.592934  ...  0.055978  1.000000
# McHenry County, Illinois            0.549923  ...  0.982636  0.522842
# Wichita County, Kansas              0.559140  ...  0.118496  0.574822
# Mineral County, Montana             0.872504  ...  0.061625  0.028026
# Ohio County, West Virginia          0.700461  ...  0.317203  0.057158
#
#                                PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Greene County, North Carolina      0.478172              0.891040   0.407456
# McHenry County, Illinois           0.886624              0.457204   0.401518
# Wichita County, Kansas             0.788191              0.753252   0.388981
# Mineral County, Montana            0.543234              0.355567   0.425932
# Ohio County, West Virginia         0.455453              0.347449   0.411415
#
#                                City  State  Region  Division  TARGET_deathRate
# Geography
# Greene County, North Carolina   603     33       2         6          0.648195
# McHenry County, Illinois        948     13       0         0          0.739132
# Wichita County, Kansas         1614     16       0         7          0.682701
# Mineral County, Montana         984     26       3         3          0.913427
# Ohio County, West Virginia     1085     48       2         6          0.810853
#
# [5 rows x 37 columns]

# %%
valset_minmax = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Transform/valset.csv", index_col = 0)
valset_minmax.head(5)
# Out:
#                               avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Linn County, Oregon              0.563843          0.826004       0.433484
# Champaign County, Illinois       0.653182          0.807648       0.505499
# Saratoga County, New York        0.933418          1.073805       0.982915
# Montmorency County, Michigan     0.069111          0.104015       0.305802
# Barrow County, Georgia           0.231774          0.339579       0.540069
#
#                               medIncome  popEst2015  povertyPercent  \
# Geography
# Linn County, Oregon            0.785557    0.536256        0.039546
# Champaign County, Illinois     1.108948    0.654300        0.961857
# Saratoga County, New York      1.108948    0.134907        0.126423
# Montmorency County, Michigan   0.055315    0.421585        0.000000
# Barrow County, Georgia         0.489118    0.330523        0.000000
#
#                               studyPerCap  binnedInc  MedianAge  \
# Geography
# Linn County, Oregon                0.5504          3   0.555932
# Champaign County, Illinois         0.2240          4   0.196610
# Saratoga County, New York          0.6240          8   0.627119
# Montmorency County, Michigan       0.9616          1   0.959322
# Barrow County, Georgia             0.4000          5   0.355932
#
#                               MedianAgeMale  ...  PctBlack  PctAsian  \
# Geography                                    ...
# Linn County, Oregon                0.556068  ...  0.456603  0.244924
# Champaign County, Illinois         0.258065  ...  0.980500  0.193658
# Saratoga County, New York          0.632873  ...  0.885327  0.077846
# Montmorency County, Michigan       0.987711  ...  0.000000  0.067381
# Barrow County, Georgia             0.427035  ...  0.980500  0.391169
#
#                               PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Linn County, Oregon               0.658341              0.496995   0.418344
# Champaign County, Illinois        0.382380              0.369846   0.306170
# Saratoga County, New York         0.680359              0.482247   0.377763
# Montmorency County, Michigan      0.599090              0.348074   0.487958
# Barrow County, Georgia            0.735752              0.567292   0.436490
#
#                               TARGET_deathRate  City  State  Region  Division
# Geography
# Linn County, Oregon                   0.747251   139     32       3         5
# Champaign County, Illinois            0.673636    40      8       0         0
# Saratoga County, New York             0.831963   228     27       1         2
# Montmorency County, Michigan          0.766196   172     17       0         0
# Barrow County, Georgia                0.693934     8      6       2         6
#
# [5 rows x 37 columns]

# %%
testset_minmax = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Transform/testset.csv", index_col = 0)
testset_minmax.head(5)
# Out:
#                               avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Linn County, Oregon              0.563843          0.826004       0.433484
# Champaign County, Illinois       0.653182          0.807648       0.505499
# Saratoga County, New York        0.933418          1.073805       0.982915
# Montmorency County, Michigan     0.069111          0.104015       0.305802
# Barrow County, Georgia           0.231774          0.339579       0.540069
#
#                               medIncome  popEst2015  povertyPercent  \
# Geography
# Linn County, Oregon            0.785557    0.536256        0.039546
# Champaign County, Illinois     1.108948    0.654300        0.961857
# Saratoga County, New York      1.108948    0.134907        0.126423
# Montmorency County, Michigan   0.055315    0.421585        0.000000
# Barrow County, Georgia         0.489118    0.330523        0.000000
#
#                               studyPerCap  binnedInc  MedianAge  \
# Geography
# Linn County, Oregon                0.5504          3   0.555932
# Champaign County, Illinois         0.2240          4   0.196610
# Saratoga County, New York          0.6240          8   0.627119
# Montmorency County, Michigan       0.9616          1   0.959322
# Barrow County, Georgia             0.4000          5   0.355932
#
#                               MedianAgeMale  ...  PctBlack  PctAsian  \
# Geography                                    ...
# Linn County, Oregon                0.556068  ...  0.456603  0.244924
# Champaign County, Illinois         0.258065  ...  0.980500  0.193658
# Saratoga County, New York          0.632873  ...  0.885327  0.077846
# Montmorency County, Michigan       0.987711  ...  0.000000  0.067381
# Barrow County, Georgia             0.427035  ...  0.980500  0.391169
#
#                               PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Linn County, Oregon               0.658341              0.496995   0.418344
# Champaign County, Illinois        0.382380              0.369846   0.306170
# Saratoga County, New York         0.680359              0.482247   0.377763
# Montmorency County, Michigan      0.599090              0.348074   0.487958
# Barrow County, Georgia            0.735752              0.567292   0.436490
#
#                               TARGET_deathRate  City  State  Region  Division
# Geography
# Linn County, Oregon                   0.747251   139     32       3         5
# Champaign County, Illinois            0.673636    40      8       0         0
# Saratoga County, New York             0.831963   228     27       1         2
# Montmorency County, Michigan          0.766196   172     17       0         0
# Barrow County, Georgia                0.693934     8      6       2         6
#
# [5 rows x 37 columns]

# %%
X_train_minmax = trainset_minmax.drop(['TARGET_deathRate'], axis = 1)
y_train_minmax = trainset_minmax['TARGET_deathRate']

# %%
X_val_minmax = valset_minmax.drop(['TARGET_deathRate'], axis = 1)
y_val_minmax = valset_minmax['TARGET_deathRate']

# %%
X_test_minmax = testset_minmax.drop(['TARGET_deathRate'], axis = 1)
y_test_minmax = testset_minmax['TARGET_deathRate']

# %%
import pickle
rfe_filename_minmax = '/content/drive/My Drive/DataMining/POC/LungCancer/FeatureSelection/Transform/minmax_rfe.h5'
rfe_fit_minmax = pickle.load(open(rfe_filename_minmax, 'rb'))

# %%
X_train_rfe_minmax = rfe_fit_minmax.transform(X_train_minmax)
X_val_rfe_minmax = rfe_fit_minmax.transform(X_val_minmax)
X_test_rfe_minmax = rfe_fit_minmax.transform(X_test_minmax)
print(X_train_rfe_minmax.shape, y_train_minmax.shape)
print(X_val_rfe_minmax.shape, y_val_minmax.shape)
print(X_test_rfe_minmax.shape, y_test_minmax.shape)
# Out:
# (2467, 18) (2467,)
# (305, 18) (305,)
# (305, 18) (305,)

# %%
import joblib
scaler_single_filename = "/content/drive/My Drive/DataMining/POC/LungCancer/Model/Scaler/scaler_single.save"
scaler_single = joblib.load(scaler_single_filename)

# %% [markdown]
# # Compare

# %%
evaluation_basic_raw = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Evaluation/Raw/basic.csv")
evaluation_basic_raw.rename(columns = {'Unnamed: 0':'model'}, inplace = True)
evaluation_basic_raw["type_1"] = "Raw"
evaluation_basic_raw["type_2"] = "basic"
evaluation_basic_raw.head(5)
# Out:
#                        model         mse        mae       rmse        r2  \
# 0          Linear Regression  333.886574  13.991826  18.272563  0.327839
# 1  Support Vector Regression  551.118317  18.478895  23.475909 -5.853417
# 2   Decision Tree Regression  753.956820  20.606230  27.458274  0.157881
# 3   Random Forest Regression  324.180913  13.689643  18.005025  0.273986
# 4         XGBoost Regression  292.321678  13.147758  17.097417  0.456422
#
#    deviation type_1 type_2
# 0   0.080978    Raw  basic
# 1   0.106958    Raw  basic
# 2   0.118546    Raw  basic
# 3   0.079200    Raw  basic
# 4   0.075626    Raw  basic

# %%
evaluation_optuna_raw = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Evaluation/Raw/optuna.csv")
evaluation_optuna_raw.rename(columns = {'Unnamed: 0':'model'}, inplace = True)
evaluation_optuna_raw["type_1"] = "Raw"
evaluation_optuna_raw["type_2"] = "optuna"
evaluation_optuna_raw.head(5)
# Out:
#                       model         mse        mae       rmse         r2  \
# 0         Linear Regression  333.886574  13.991826  18.272563   0.327839
# 1            Neural Network  725.310692  21.425189  26.931593 -92.202692
# 2  Decision Tree Regression  747.080066  20.746885  27.332765   0.134238
# 3  Random Forest Regression  329.407397  13.777856  18.149584   0.257573
# 4        XGBoost Regression  347.742756  13.954350  18.647862   0.334566
#
#    deviation type_1  type_2
# 0   0.080978    Raw  optuna
# 1   0.123376    Raw  optuna
# 2   0.118710    Raw  optuna
# 3   0.079938    Raw  optuna
# 4   0.080016    Raw  optuna

# %%
evaluation_basic_minmax = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Evaluation/Transform/basic.csv")
evaluation_basic_minmax.rename(columns = {'Unnamed: 0':'model'}, inplace = True)
evaluation_basic_minmax["type_1"] = "Transform"
evaluation_basic_minmax["type_2"] = "basic"
evaluation_basic_minmax.head(5)
# Out:
#                        model          mse        mae       rmse        r2  \
# 0          Linear Regression  1218.156182  26.722086  34.902094 -0.979636
# 1  Support Vector Regression  1453.280494  28.861588  38.121916 -4.764735
# 2   Decision Tree Regression  1675.424800  30.285213  40.931953 -0.066914
# 3   Random Forest Regression   990.462516  24.020698  31.471614 -0.581062
# 4         XGBoost Regression   783.883892  21.351691  27.997927  0.077906
#
#    deviation     type_1 type_2
# 0   0.103988  Transform  basic
# 1   0.110393  Transform  basic
# 2   0.123841  Transform  basic
# 3   0.093196  Transform  basic
# 4   0.084031  Transform  basic

# %%
evaluation_optuna_minmax = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Evaluation/Transform/optuna.csv")
evaluation_optuna_minmax.rename(columns = {'Unnamed: 0':'model'}, inplace = True)
evaluation_optuna_minmax["type_1"] = "Transform"
evaluation_optuna_minmax["type_2"] = "optuna"
evaluation_optuna_minmax.head(5)
# Out:
#                       model          mse        mae       rmse          r2  \
# 0         Linear Regression  1218.156182  26.722086  34.902094   -0.979636
# 1            Neural Network  1789.929299  33.197497  42.307556  -26.266012
# 2  Decision Tree Regression  3279.798949  45.385811  57.269529 -275.074483
# 3  Random Forest Regression  2073.411023  33.935602  45.534723 -303.540524
# 4        XGBoost Regression  2359.028818  37.075643  48.569834  -49.442872
#
#    deviation     type_1  type_2
# 0   0.103988  Transform  optuna
# 1   0.137975  Transform  optuna
# 2   0.204091  Transform  optuna
# 3   0.121016  Transform  optuna
# 4   0.129344  Transform  optuna

# %%
evaluation = evaluation_basic_raw.copy()
evaluation = evaluation.append(evaluation_optuna_raw, ignore_index = True)
evaluation = evaluation.append(evaluation_basic_minmax, ignore_index = True)
evaluation = evaluation.append(evaluation_optuna_minmax, ignore_index = True)
evaluation
# Out:
#                         model          mse        mae       rmse          r2  \
# 0           Linear Regression   333.886574  13.991826  18.272563    0.327839
# 1   Support Vector Regression   551.118317  18.478895  23.475909   -5.853417
# 2    Decision Tree Regression   753.956820  20.606230  27.458274    0.157881
# 3    Random Forest Regression   324.180913  13.689643  18.005025    0.273986
# 4          XGBoost Regression   292.321678  13.147758  17.097417    0.456422
# 5           Linear Regression   333.886574  13.991826  18.272563    0.327839
# 6              Neural Network   725.310692  21.425189  26.931593  -92.202692
# 7    Decision Tree Regression   747.080066  20.746885  27.332765    0.134238
# 8    Random Forest Regression   329.407397  13.777856  18.149584    0.257573
# 9          XGBoost Regression   347.742756  13.954350  18.647862    0.334566
# 10          Linear Regression  1218.156182  26.722086  34.902094   -0.979636
# 11  Support Vector Regression  1453.280494  28.861588  38.121916   -4.764735
# 12   Decision Tree Regression  1675.424800  30.285213  40.931953   -0.066914
# 13   Random Forest Regression   990.462516  24.020698  31.471614   -0.581062
# 14         XGBoost Regression   783.883892  21.351691  27.997927    0.077906
# 15          Linear Regression  1218.156182  26.722086  34.902094   -0.979636
# 16             Neural Network  1789.929299  33.197497  42.307556  -26.266012
# 17   Decision Tree Regression  3279.798949  45.385811  57.269529 -275.074483
# 18   Random Forest Regression  2073.411023  33.935602  45.534723 -303.540524
# 19         XGBoost Regression  2359.028818  37.075643  48.569834  -49.442872
#
#     deviation     type_1  type_2
# 0    0.080978        Raw   basic
# 1    0.106958        Raw   basic
# 2    0.118546        Raw   basic
# 3    0.079200        Raw   basic
# 4    0.075626        Raw   basic
# 5    0.080978        Raw  optuna
# 6    0.123376        Raw  optuna
# 7    0.118710        Raw  optuna
# 8    0.079938        Raw  optuna
# 9    0.080016        Raw  optuna
# 10   0.103988  Transform   basic
# 11   0.110393  Transform   basic
# 12   0.123841  Transform   basic
# 13   0.093196  Transform   basic
# 14   0.084031  Transform   basic
# 15   0.103988  Transform  optuna
# 16   0.137975  Transform  optuna
# 17   0.204091  Transform  optuna
# 18   0.121016  Transform  optuna
# 19   0.129344  Transform  optuna

# %%
best_fit_model = evaluation[evaluation['mse']  == evaluation['mse'].min()]
best_fit_model
# Out:
#                 model         mse        mae       rmse        r2  deviation  \
# 4  XGBoost Regression  292.321678  13.147758  17.097417  0.456422   0.075626
#
#   type_1 type_2
# 4    Raw  basic

# %% [markdown]
# # Create link

# %%
link_mod = f'/content/drive/My Drive/DataMining/POC/LungCancer/Model/{best_fit_model["type_1"].values[0]}/'
link_mod
# Out:
# '/content/drive/My Drive/DataMining/POC/LungCancer/Model/Raw/'

# %%
name_file = ""
if best_fit_model["model"].values[0] =="Linear Regression":
  name_file = name_file+"lr"
elif best_fit_model["model"].values[0] =="Neural Network":
  name_file = name_file+"nn"
elif best_fit_model["model"].values[0] =="Decision Tree Regression":
  name_file = name_file+"dtr"
elif best_fit_model["model"].values[0] =="Random Forest Regression	":
  name_file = name_file+"rfr"
else:
  name_file = name_file+"xgbr"

# %%
if best_fit_model["type_2"].values[0] == "basic":
  name_file = name_file + "_Baseline.h5"
else:
  name_file = name_file + "_Optuna.h5"

# %%
link_mod = link_mod + name_file
link_mod
# Out:
# '/content/drive/My Drive/DataMining/POC/LungCancer/Model/Raw/xgbr_Baseline.h5'

# %%
from tensorflow.keras.models import load_model

# %%
if best_fit_model["model"].values[0] =="Neural Network":
  best_mod = load_model(f'link_mod ')
else:
  best_mod = pickle.load(open(link_mod , 'rb'))

# %% [markdown]
# # Feature Selection

# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
import shap

# %%
explainer = shap.Explainer(best_mod.predict, X_train_rfe_raw)

# %%
shap_values = explainer(X_train_rfe_raw)
# Out:
# Permutation explainer: 2468it [07:42,  5.31it/s]

# %%
shap.summary_plot(shap_values, X_train_rfe_raw)

# %%
shap.plots.bar(shap_values)

# %%
from sklearn.feature_selection import SelectFromModel

# %%
shap_values.base_values
# Out:
# array([178.63518974, 178.63518974, 178.63518974, ..., 178.63518974,
#        178.63518974, 178.63518974])

# %%
rfe_fit_raw.set_params
# Out:
# <bound method BaseEstimator.set_params of RFE(estimator=RandomForestRegressor())>

# %%
cols = []
i = 0
while i < len(X_train_rfe_raw[0]):
  cols.append(f"Feature {i}")
  i = i + 1
print(cols)
# Out:
# ['Feature 0', 'Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', 'Feature 5', 'Feature 6', 'Feature 7', 'Feature 8', 'Feature 9', 'Feature 10', 'Feature 11', 'Feature 12', 'Feature 13', 'Feature 14', 'Feature 15', 'Feature 16', 'Feature 17']

# %%
shap_sum = shap_values.values.mean(axis=0)#np.abs(
importance_df = pd.DataFrame([cols, shap_sum.tolist()]).T
importance_df.columns = ['column_name', 'shap_importance']
importance_df = importance_df.sort_values('shap_importance', ascending=False)
importance_df
# Out:
#    column_name shap_importance
# 5    Feature 5         1.00282
# 4    Feature 4        0.525256
# 13  Feature 13        0.269179
# 16  Feature 16        0.226083
# 11  Feature 11        0.166761
# 14  Feature 14        0.124205
# 2    Feature 2        0.059445
# 10  Feature 10        0.044451
# 17  Feature 17       -0.022496
# 7    Feature 7       -0.022779
# 12  Feature 12       -0.042549
# 1    Feature 1       -0.067226
# 9    Feature 9       -0.073708
# 15  Feature 15       -0.123094
# 0    Feature 0       -0.273591
# 8    Feature 8       -0.606197
# 6    Feature 6       -0.625684
# 3    Feature 3       -0.689373

# %% [markdown]
# # Measure

# %%
#evaluation metrics for regression model
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error, r2_score

# %%
def deviation_function(y_val, pred):
  deviation = []
  for i in range(0, len(y_val)):
    deviation.append(abs(pred[i] - y_val[i]) / y_val[i])
  return deviation

# %%
def deviation_value(y_val, pred):
  deviation = []
  for i in range(0, len(y_val)):
    deviation.append(abs(pred[i] - y_val[i]) / y_val[i])
  return np.array(deviation).mean()

# %% [markdown]
# # Predict Test

# %%
trainvalset_raw = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Raw/trainvalset.csv", index_col = 0)
trainvalset_raw.head(5)
# Out:
#                            avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Cumberland County, Maine        1192.5           329.875     479.600000
# Perry County, Kentucky           192.0            93.000     570.787500
# Camden County, New Jersey       1192.5           329.875     530.900000
# Pinal County, Arizona           1192.5           329.875     330.900000
# Washington County, Kansas       1192.5            18.000     453.549422
#
#                            medIncome  popEst2015  povertyPercent  studyPerCap  \
# Geography
# Cumberland County, Maine       61436  153227.875            10.8   209.768024
# Perry County, Kentucky         31265   27565.000            27.5   209.768024
# Camden County, New Jersey      61685  153227.875            13.0   209.768024
# Pinal County, Arizona          49876  153227.875            17.6    19.676131
# Washington County, Kansas      43264    5598.000            10.8     0.000000
#
#                            binnedInc  MedianAge  MedianAgeMale  ...  \
# Geography                                                       ...
# Cumberland County, Maine           7       41.9           40.3  ...
# Perry County, Kentucky             9       41.4           40.2  ...
# Camden County, New Jersey          8       38.3           36.6  ...
# Pinal County, Arizona              5       37.6           36.9  ...
# Washington County, Kansas          3       46.3           44.1  ...
#
#                             PctBlack  PctAsian  PctOtherRace  \
# Geography
# Cumberland County, Maine    2.659033  2.086544      0.351602
# Perry County, Kentucky      1.433615  0.559894      0.000000
# Camden County, New Jersey  19.409841  2.680286      5.051674
# Pinal County, Arizona       4.606283  1.718441      5.051674
# Washington County, Kansas   0.756243  0.175871      0.281393
#
#                            PctMarriedHouseholds  BirthRate  TARGET_deathRate  \
# Geography
# Cumberland County, Maine              47.825159   3.772834             173.3
# Perry County, Kentucky                50.803249   4.955914             280.8
# Camden County, New Jersey             45.973960   5.434939             182.8
# Pinal County, Arizona                 54.212024   5.719536             133.5
# Washington County, Kansas             57.330057   5.961538             172.4
#
#                            City  State  Region  Division
# Geography
# Cumberland County, Maine    379     19       1         4
# Perry County, Kentucky     1154     17       2         1
# Camden County, New Jersey   221     30       1         2
# Pinal County, Arizona      1168      2       3         3
# Washington County, Kansas  1577     16       0         7
#
# [5 rows x 37 columns]

# %%
trainvalset_minmax = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Transform/trainvalset.csv", index_col = 0)
trainvalset_minmax.head(5)
# Out:
#                            avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Cumberland County, Maine      1.000000          1.000000       0.774356
# Perry County, Kentucky        0.156764          0.275335       0.172152
# Camden County, New Jersey     1.000000          1.000000       0.779326
# Pinal County, Arizona         1.000000          1.000000       0.543622
# Washington County, Kansas     1.000000          0.045889       0.411648
#
#                            medIncome  popEst2015  povertyPercent  studyPerCap  \
# Geography
# Cumberland County, Maine    1.000000    0.256324        1.000000       0.6272
# Perry County, Kentucky      0.175434    0.819562        1.000000       0.6112
# Camden County, New Jersey   1.000000    0.330523        1.000000       0.5120
# Pinal County, Arizona       1.000000    0.485666        0.093799       0.4896
# Washington County, Kansas   0.031293    0.256324        0.000000       0.7680
#
#                            binnedInc  MedianAge  MedianAgeMale  ...  PctBlack  \
# Geography                                                       ...
# Cumberland County, Maine           7   0.606780       0.645161  ...  0.778478
# Perry County, Kentucky             9   0.603390       0.599078  ...  0.208894
# Camden County, New Jersey          8   0.481356       0.546851  ...  1.000000
# Pinal County, Arizona              5   0.491525       0.497696  ...  0.641141
# Washington County, Kansas          3   0.735593       0.801843  ...  0.065616
#
#                            PctAsian  PctOtherRace  PctMarriedHouseholds  \
# Geography
# Cumberland County, Maine   0.069601      0.567364              0.402449
# Perry County, Kentucky     0.000000      0.635406              0.528648
# Camden County, New Jersey  1.000000      0.525069              0.579746
# Pinal County, Arizona      1.000000      0.713288              0.610104
# Washington County, Kansas  0.055703      0.784527              0.635919
#
#                            BirthRate  TARGET_deathRate  City  State  Region  \
# Geography
# Cumberland County, Maine    0.374794          0.753205   379     19       1
# Perry County, Kentucky      0.729462          1.000000  1154     17       2
# Camden County, New Jersey   0.406137          0.892046   221     30       1
# Pinal County, Arizona       0.243484          0.350756  1168      2       3
# Washington County, Kansas   0.371824          0.682701  1577     16       0
#
#                            Division
# Geography
# Cumberland County, Maine          4
# Perry County, Kentucky            1
# Camden County, New Jersey         2
# Pinal County, Arizona             3
# Washington County, Kansas         7
#
# [5 rows x 37 columns]

# %%
X_trainval_raw = trainvalset_raw.drop(['TARGET_deathRate'], axis = 1)
y_trainval_raw = trainvalset_raw['TARGET_deathRate']

# %%
X_trainval_minmax = trainvalset_minmax.drop(['TARGET_deathRate'], axis = 1)
y_trainval_minmax = trainvalset_minmax['TARGET_deathRate']

# %%
X_trainval_rfe_raw = rfe_fit_raw.transform(X_trainval_raw)
X_trainval_rfe_minmax = rfe_fit_minmax.transform(X_trainval_minmax)

# %%
if best_fit_model["model"].values[0] =="Neural Network":
  best_mod = best_mod.fit(
                    X_trainval_rfe_raw, y_trainval_raw,
                    batch_size=16,
                    epochs=300,
                    validation_split=0.2,
                    verbose=1,
  )
else:
  best_mod = best_mod.fit(X_trainval_rfe_raw,y_trainval_raw)

# %%
pred = best_mod.predict(X_test_rfe_raw)

# %% [markdown]
# # Result

# %%
deviation_test = deviation_function(y_test_raw, pred)
dict = {'Actual':y_test_raw,
        'Predict': pred,
        'Deviation':deviation_test}
mod_deviation = pd.DataFrame(dict)
plt.figure(figsize=(15,4))
sns.distplot(mod_deviation.Deviation, label=str(np.round(mod_deviation.Deviation,2)))
# Out:
# <Axes: xlabel='Deviation', ylabel='Density'>

# %%
#evaluating the model with the following metrics
#mean squared error
mse=mean_squared_error(y_test_raw, pred)     
#mean absolute error     
mae=mean_absolute_error(y_test_raw, pred)  
#root mean squared error      
rmse=np.sqrt(mean_squared_error(y_test_raw, pred))
#r2 score
r2 = r2_score(y_test_raw, pred)
print(f'mse: {mse}')
print(f'mae: {mae}')
print(f'rmse: {rmse}')
print(f"r2_score: {r2}")
# Out:
# mse: 265.9992607574946
# mae: 12.746174541535924
# rmse: 16.30948376735127
# r2_score: 0.6360784216901114

# %%
evaluation_df =pd.DataFrame({"mse": mse,"mae": mae,"rmse": rmse,  "r2": r2, "deviation": deviation_value(y_test_raw, pred)},index=['XGBoost Regression'])
evaluation_df
# Out:
#                            mse        mae       rmse        r2  deviation
# XGBoost Regression  265.999261  12.746175  16.309484  0.636078   0.072805

# %%
Axis = [y_test_raw.mean()] * len(y_test_raw)
plt.figure(figsize=(16, 9))
plt.ylabel('XGBoost Regression Result')
plt.plot(y_test_raw, 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Predict Feature Selection After Training

# %%
cols_threshold = []
index_threshold = []
for i in importance_df.index:
  if abs(importance_df._get_value(i, 'shap_importance')) > 0.1:
    print(f"{i}---{importance_df._get_value(i, 'column_name')}")
    cols_threshold.append(importance_df._get_value(i, 'column_name'))
    index_threshold.append(i)
# Out:
# 5---Feature 5
# 4---Feature 4
# 13---Feature 13
# 16---Feature 16
# 11---Feature 11
# 14---Feature 14
# 15---Feature 15
# 0---Feature 0
# 8---Feature 8
# 6---Feature 6
# 3---Feature 3

# %%
X_train_fs = X_trainval_rfe_raw[:,index_threshold]
X_test_fs = X_test_rfe_raw[:,index_threshold]

# %%
if best_fit_model["model"].values[0] =="Neural Network":
  fs_mod = load_model(f'link_mod ')
else:
  fs_mod = pickle.load(open(link_mod , 'rb'))

# %%
if best_fit_model["model"].values[0] =="Neural Network":
  fs_mod = fs_mod.fit(
                    X_train_fs, y_trainval_raw,
                    batch_size=16,
                    epochs=300,
                    validation_split=0.2,
                    verbose=1,
  )
else:
  fs_mod = fs_mod.fit(X_train_fs,y_trainval_raw)

# %%
fs_pred = fs_mod.predict(X_test_fs)

# %% [markdown]
# # Result Feature Selection After Training

# %%
fs_deviation_test = deviation_function(y_test_raw, fs_pred)
dict = {'Actual':y_test_raw,
        'Predict': pred,
        'Deviation':fs_deviation_test}
fs_mod_deviation = pd.DataFrame(dict)
plt.figure(figsize=(15,4))
sns.distplot(fs_mod_deviation.Deviation, label=str(np.round(fs_mod_deviation.Deviation,2)))
# Out:
# <Axes: xlabel='Deviation', ylabel='Density'>

# %%
#evaluating the model with the following metrics
#mean squared error
fs_mse=mean_squared_error(y_test_raw, fs_pred)     
#mean absolute error     
fs_mae=mean_absolute_error(y_test_raw, fs_pred)  
#root mean squared error      
fs_rmse=np.sqrt(mean_squared_error(y_test_raw, fs_pred))
#r2 score
fs_r2 = r2_score(y_test_raw, fs_pred)
print(f'mse: {fs_mse}')
print(f'mae: {fs_mae}')
print(f'rmse: {fs_rmse}')
print(f"r2_score: {fs_r2}")
# Out:
# mse: 304.4039423237833
# mae: 13.16583587146196
# rmse: 17.44717576926946
# r2_score: 0.5835358232998312

# %%
fs_evaluation_df =pd.DataFrame({"mse": fs_mse,"mae": fs_mae,"rmse": fs_rmse,  "r2": fs_r2, "deviation": deviation_value(y_test_raw, fs_pred)},index=['XGBoost Regression'])
fs_evaluation_df
# Out:
#                            mse        mae       rmse        r2  deviation
# XGBoost Regression  304.403942  13.165836  17.447176  0.583536   0.074945

# %%
Axis = [y_test_raw.mean()] * len(y_test_raw)
plt.figure(figsize=(16, 9))
plt.ylabel('XGBoost Regression Result')
plt.plot(y_test_raw, 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(fs_pred, 'orange', label='Predicted data')
plt.legend()

# %%
fs_mod_deviation.to_csv("compare_fe_fs.csv")
mod_deviation.to_csv("compare_fe_full.csv")
