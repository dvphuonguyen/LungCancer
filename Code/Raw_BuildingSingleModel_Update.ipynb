# %% [markdown]
# https://www.kaggle.com/code/meenaaa/cancer-death-rate-xgboost/notebook

# %% [markdown]
# https://www.researchgate.net/publication/341042405_On_linear_regression_models_with_hierarchical_categorical_variables

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data wrangling tools
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# statistical analysis
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# scikit-learn
from sklearn.model_selection import train_test_split

import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
trainset = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Raw/trainset.csv", index_col = 0)
trainset.head(5)
# Out:
#                                avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Greene County, North Carolina        105.0            43.000     440.800000
# McHenry County, Illinois            1192.5           329.875     474.400000
# Wichita County, Kansas              1192.5             6.000     453.549422
# Mineral County, Montana               35.0            12.000     538.800000
# Ohio County, West Virginia           308.0           123.000     500.900000
#
#                                medIncome  popEst2015  povertyPercent  \
# Geography
# Greene County, North Carolina      37263   21134.000            28.3
# McHenry County, Illinois           72741  153227.875             6.9
# Wichita County, Kansas             53447    2157.000            11.5
# Mineral County, Montana            36449    4251.000            17.3
# Ohio County, West Virginia         40195   43066.000            18.4
#
#                                studyPerCap  binnedInc  MedianAge  \
# Geography
# Greene County, North Carolina     0.000000          0      39.00
# McHenry County, Illinois          0.000000          8      39.30
# Wichita County, Kansas            0.000000          6      35.70
# Mineral County, Montana           0.000000          0      53.55
# Ohio County, West Virginia      209.768024          1      43.30
#
#                                MedianAgeMale  ...   PctBlack  PctAsian  \
# Geography                                     ...
# Greene County, North Carolina           37.0  ...  24.785427  0.150038
# McHenry County, Illinois                38.2  ...   1.345992  2.633745
# Wichita County, Kansas                  34.5  ...   0.000000  0.317604
# Mineral County, Montana                 51.9  ...   0.070788  0.165172
# Ohio County, West Virginia              41.3  ...   4.152439  0.850196
#
#                                PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Greene County, North Carolina      5.051674             43.921351   8.353222
# McHenry County, Illinois           2.641228             61.798687   4.286142
# Wichita County, Kansas             2.903811             57.490397   7.061503
# Mineral County, Montana            0.141576             46.769034   3.333333
# Ohio County, West Virginia         0.288746             42.926988   3.257227
#
#                                City  State  Region  Division  TARGET_deathRate
# Geography
# Greene County, North Carolina   603     33       2         6             183.2
# McHenry County, Illinois        948     13       0         0             181.4
# Wichita County, Kansas         1614     16       0         7             177.6
# Mineral County, Montana         984     26       3         3             188.8
# Ohio County, West Virginia     1085     48       2         6             184.4
#
# [5 rows x 37 columns]

# %%
valset = pd.read_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Dataset/Raw/valset.csv", index_col = 0)
valset.head(5)
# Out:
#                               avgAnnCount  avgDeathsPerYear  incidenceRate  \
# Geography
# Linn County, Oregon                 675.0               273          477.4
# Champaign County, Illinois          781.0               267          450.2
# Saratoga County, New York          1113.5               354          508.7
# Montmorency County, Michigan         88.0                37          484.4
# Barrow County, Georgia              281.0               114          457.7
#
#                               medIncome  popEst2015  povertyPercent  \
# Geography
# Linn County, Oregon               44358    120547.0            19.1
# Champaign County, Illinois        47966    169831.5            22.6
# Saratoga County, New York         71885    169831.5             7.2
# Montmorency County, Michigan      37961      9259.0            15.7
# Barrow County, Georgia            49698     75370.0            13.0
#
#                               studyPerCap  binnedInc  MedianAge  \
# Geography
# Linn County, Oregon              8.295520          3      39.50
# Champaign County, Illinois     201.766857          4      29.30
# Saratoga County, New York       26.519454          8      41.80
# Montmorency County, Michigan     0.000000          1      52.35
# Barrow County, Georgia           0.000000          5      34.80
#
#                               MedianAgeMale  ...   PctBlack  PctAsian  \
# Geography                                    ...
# Linn County, Oregon                    38.8  ...   0.437922  1.223828
# Champaign County, Illinois             28.2  ...  12.588086  2.628022
# Saratoga County, New York              40.9  ...   1.611447  2.372930
# Montmorency County, Michigan           50.7  ...   0.361664  0.000000
# Barrow County, Georgia                 32.9  ...  11.578626  2.628022
#
#                               PctOtherRace  PctMarriedHouseholds  BirthRate  \
# Geography
# Linn County, Oregon               1.237276             51.807095   4.659173
# Champaign County, Illinois        0.978296             39.728702   3.467191
# Saratoga County, New York         0.393254             52.770765   4.520914
# Montmorency County, Michigan      0.340389             49.213759   3.263086
# Barrow County, Georgia            1.976060             55.195246   5.318187
#
#                               TARGET_deathRate  City  State  Region  Division
# Geography
# Linn County, Oregon                      186.5   139     32       3         5
# Champaign County, Illinois               152.5    40      8       0         0
# Saratoga County, New York                174.2   228     27       1         2
# Montmorency County, Michigan             207.6   172     17       0         0
# Barrow County, Georgia                   192.0     8      6       2         6
#
# [5 rows x 37 columns]

# %%
trainset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2467 entries, Greene County, North Carolina to Van Wert County, Ohio
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              2467 non-null   float64
#  1   avgDeathsPerYear         2467 non-null   float64
#  2   incidenceRate            2467 non-null   float64
#  3   medIncome                2467 non-null   int64
#  4   popEst2015               2467 non-null   float64
#  5   povertyPercent           2467 non-null   float64
#  6   studyPerCap              2467 non-null   float64
#  7   binnedInc                2467 non-null   int64
#  8   MedianAge                2467 non-null   float64
#  9   MedianAgeMale            2467 non-null   float64
#  10  MedianAgeFemale          2467 non-null   float64
#  11  AvgHouseholdSize         2467 non-null   float64
#  12  PercentMarried           2467 non-null   float64
#  13  PctNoHS18_24             2467 non-null   float64
#  14  PctHS18_24               2467 non-null   float64
#  15  PctSomeCol18_24          2467 non-null   float64
#  16  PctBachDeg18_24          2467 non-null   float64
#  17  PctHS25_Over             2467 non-null   float64
#  18  PctBachDeg25_Over        2467 non-null   float64
#  19  PctEmployed16_Over       2467 non-null   float64
#  20  PctUnemployed16_Over     2467 non-null   float64
#  21  PctPrivateCoverage       2467 non-null   float64
#  22  PctPrivateCoverageAlone  2467 non-null   float64
#  23  PctEmpPrivCoverage       2467 non-null   float64
#  24  PctPublicCoverage        2467 non-null   float64
#  25  PctPublicCoverageAlone   2467 non-null   float64
#  26  PctWhite                 2467 non-null   float64
#  27  PctBlack                 2467 non-null   float64
#  28  PctAsian                 2467 non-null   float64
#  29  PctOtherRace             2467 non-null   float64
#  30  PctMarriedHouseholds     2467 non-null   float64
#  31  BirthRate                2467 non-null   float64
#  32  City                     2467 non-null   int64
#  33  State                    2467 non-null   int64
#  34  Region                   2467 non-null   int64
#  35  Division                 2467 non-null   int64
#  36  TARGET_deathRate         2467 non-null   float64
# dtypes: float64(31), int64(6)
# memory usage: 732.4+ KB

# %%
valset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305 entries, Linn County, Oregon to Macon County, Missouri
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              305 non-null    float64
#  1   avgDeathsPerYear         305 non-null    int64
#  2   incidenceRate            305 non-null    float64
#  3   medIncome                305 non-null    int64
#  4   popEst2015               305 non-null    float64
#  5   povertyPercent           305 non-null    float64
#  6   studyPerCap              305 non-null    float64
#  7   binnedInc                305 non-null    int64
#  8   MedianAge                305 non-null    float64
#  9   MedianAgeMale            305 non-null    float64
#  10  MedianAgeFemale          305 non-null    float64
#  11  AvgHouseholdSize         305 non-null    float64
#  12  PercentMarried           305 non-null    float64
#  13  PctNoHS18_24             305 non-null    float64
#  14  PctHS18_24               305 non-null    float64
#  15  PctSomeCol18_24          305 non-null    float64
#  16  PctBachDeg18_24          305 non-null    float64
#  17  PctHS25_Over             305 non-null    float64
#  18  PctBachDeg25_Over        305 non-null    float64
#  19  PctEmployed16_Over       305 non-null    float64
#  20  PctUnemployed16_Over     305 non-null    float64
#  21  PctPrivateCoverage       305 non-null    float64
#  22  PctPrivateCoverageAlone  305 non-null    float64
#  23  PctEmpPrivCoverage       305 non-null    float64
#  24  PctPublicCoverage        305 non-null    float64
#  25  PctPublicCoverageAlone   305 non-null    float64
#  26  PctWhite                 305 non-null    float64
#  27  PctBlack                 305 non-null    float64
#  28  PctAsian                 305 non-null    float64
#  29  PctOtherRace             305 non-null    float64
#  30  PctMarriedHouseholds     305 non-null    float64
#  31  BirthRate                305 non-null    float64
#  32  TARGET_deathRate         305 non-null    float64
#  33  City                     305 non-null    int64
#  34  State                    305 non-null    int64
#  35  Region                   305 non-null    int64
#  36  Division                 305 non-null    int64
# dtypes: float64(30), int64(7)
# memory usage: 90.5+ KB

# %%
X_train = trainset.drop(['TARGET_deathRate'], axis = 1)
y_train = trainset['TARGET_deathRate']

# %%
X_val = valset.drop(['TARGET_deathRate'], axis = 1)
y_val = valset['TARGET_deathRate']

# %%
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (2467, 36) (2467,)
# (305, 36) (305,)

# %%
import pickle
rfe_filename = '/content/drive/My Drive/DataMining/POC/LungCancer/FeatureSelection/Raw/raw_rfe.h5'
rfe_fit = pickle.load(open(rfe_filename, 'rb'))

# %%
X_train_rfe = rfe_fit.transform(X_train)
X_val_rfe = rfe_fit.transform(X_val)
print(X_train_rfe.shape, y_train.shape)
print(X_val_rfe.shape, y_val.shape)
# Out:
# (2467, 18) (2467,)
# (305, 18) (305,)

# %% [markdown]
# # Measure

# %%
#evaluation metrics for regression model
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error, r2_score

# %%
def deviation_function(y_val, pred):
  deviation = []
  for i in range(0, len(y_val)):
    deviation.append(abs(pred[i] - y_val[i]) / y_val[i])
  return np.array(deviation).mean()

# %% [markdown]
# # Linear Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
#linear regression model
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
#training the model
lr_model = lr.fit(X_train_rfe,y_train) 
lr_pred = lr_model.predict(X_val_rfe)

# %% [markdown]
# ## Evaluate

# %%
#evaluating the model with the following metrics
#mean squared error
lr_mse=mean_squared_error(lr_pred, y_val)     
#mean absolute error     
lr_mae=mean_absolute_error(lr_pred, y_val)  
#root mean squared error      
lr_rmse=np.sqrt(mean_squared_error(lr_pred, y_val))
#r2 score
lr_r2 = r2_score(lr_pred, y_val)
print(f'mse: {lr_mse}')
print(f'mae: {lr_mae}')
print(f'rmse: {lr_rmse}')
print(f"R-Squared: {lr_r2}")
# Out:
# mse: 333.8865742210965
# mae: 13.991825774141407
# rmse: 18.272563427748622
# R-Squared: 0.3278388611783014

# %%
lr_df =pd.DataFrame({"mse": lr_mse,"mae": lr_mae,"rmse": lr_rmse, "r2": lr_r2, "deviation": deviation_function(y_val, lr_pred)},index=['Linear Regression'])

# %%
Axis = [y_val.mean()] * len(y_val)
plt.figure(figsize=(16, 9))
plt.ylabel('Linear Regression Result')
plt.plot(y_val, 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(lr_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Support Vector Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html

# %%
#support vector regression model
from sklearn.svm import SVR

# %%
svr = SVR()

# %%
#training the model
svr_model = svr.fit(X_train_rfe,y_train) 
svr_pred = svr_model.predict(X_val_rfe)

# %% [markdown]
# ## Evaluate

# %%
#evaluating the model with the following metrics
#mean squared error
svr_mse=mean_squared_error(svr_pred, y_val)     
#mean absolute error     
svr_mae=mean_absolute_error(svr_pred, y_val)  
#root mean squared error      
svr_rmse=np.sqrt(mean_squared_error(svr_pred, y_val))
#r2 score
svr_r2 = r2_score(svr_pred, y_val)
print(f'mse: {svr_mse}')
print(f'mae: {svr_mae}')
print(f'rmse: {svr_rmse}')
print(f"R-Squared: {svr_r2}")
# Out:
# mse: 551.1183171392616
# mae: 18.47889544573233
# rmse: 23.475909293129874
# R-Squared: -5.853417048599272

# %%
svr_df =pd.DataFrame({"mse": svr_mse,"mae": svr_mae,"rmse": svr_rmse, "r2": svr_r2, "deviation": deviation_function(y_val, svr_pred)},index=['Support Vector Regression'])

# %%
Axis = [y_val.mean()] * len(y_val)
plt.figure(figsize=(16, 9))
plt.ylabel('Support Vector Regression Result')
plt.plot(y_val, 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(svr_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html

# %%
# decision tree regression model
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()

# %%
#training the model
dtr_model = dtr.fit(X_train_rfe,y_train) 
dtr_pred = dtr_model.predict(X_val_rfe)

# %% [markdown]
# ## Evaluate

# %%
#evaluating the model with the following metrics
#mean squared error
dtr_mse=mean_squared_error(dtr_pred, y_val)     
#mean absolute error     
dtr_mae=mean_absolute_error(dtr_pred, y_val)  
#root mean squared error      
dtr_rmse=np.sqrt(mean_squared_error(dtr_pred, y_val))
#r2 score
dtr_r2 = r2_score(dtr_pred, y_val)
print(f'mse: {dtr_mse}')
print(f'mae: {dtr_mae}')
print(f'rmse: {dtr_rmse}')
print(f"r2_score: {dtr_r2}")
# Out:
# mse: 753.956819672131
# mae: 20.60622950819672
# rmse: 27.45827415683897
# r2_score: 0.15788086551537517

# %%
dtr_df =pd.DataFrame({"mse": dtr_mse,"mae": dtr_mae,"rmse": dtr_rmse, "r2": dtr_r2, "deviation": deviation_function(y_val, dtr_pred)},index=['Decision Tree Regression'])

# %%
Axis = [y_val.mean()] * len(y_val)
plt.figure(figsize=(16, 9))
plt.ylabel('Decision Tree Regression Result')
plt.plot(y_val, 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(dtr_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html

# %%
# random forest regression model
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
#training the model
rfr_model = rfr.fit(X_train_rfe,y_train) 
rfr_pred = rfr_model.predict(X_val_rfe)

# %% [markdown]
# ## Evaluate

# %%
#evaluating the model with the following metrics
#mean squared error
rfr_mse=mean_squared_error(rfr_pred, y_val)     
#mean absolute error     
rfr_mae=mean_absolute_error(rfr_pred, y_val)  
#root mean squared error      
rfr_rmse=np.sqrt(mean_squared_error(rfr_pred, y_val))
#r2 score
rfr_r2 = r2_score(rfr_pred, y_val)
print(f'mse: {rfr_mse}')
print(f'mae: {rfr_mae}')
print(f'rmse: {rfr_rmse}')
print(f"r2_score: {rfr_r2}")
# Out:
# mse: 324.1809127770491
# mae: 13.689642622950817
# rmse: 18.00502465360848
# r2_score: 0.2739863855507334

# %%
rfr_df =pd.DataFrame({"mse": rfr_mse,"mae": rfr_mae,"rmse": rfr_rmse, "r2": rfr_r2, "deviation": deviation_function(y_val, rfr_pred)},index=['Random Forest Regression'])

# %%
Axis = [y_val.mean()] * len(y_val)
plt.figure(figsize=(16, 9))
plt.ylabel('Random Forest Regression Result')
plt.plot(y_val, 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(rfr_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # XGBoost Regression

# %% [markdown]
# https://stackabuse.com/bytes/end-to-end-xgboost-regression-pipeline-with-scikit-learn/

# %%
# pip install xgboost

# %%
# xgboost model
from xgboost import XGBRegressor

# %%
xgbr = XGBRegressor()

# %%
#training the model
xgbr_model = xgbr.fit(X_train_rfe,y_train) 
xgbr_pred = xgbr_model.predict(X_val_rfe)

# %% [markdown]
# ## Evaluate

# %%
#evaluating the model with the following metrics
#mean squared error
xgbr_mse=mean_squared_error(xgbr_pred, y_val)     
#mean absolute error     
xgbr_mae=mean_absolute_error(xgbr_pred, y_val)  
#root mean squared error      
xgbr_rmse=np.sqrt(mean_squared_error(xgbr_pred, y_val))
#r2 score
xgbr_r2 = r2_score(xgbr_pred, y_val)
print(f'mse: {xgbr_mse}')
print(f'mae: {xgbr_mae}')
print(f'rmse: {xgbr_rmse}')
print(f"r2_score: {xgbr_r2}")
# Out:
# mse: 292.3216784697091
# mae: 13.147758473880955
# rmse: 17.09741730407576
# r2_score: 0.45642225791216584

# %%
xgbr_df =pd.DataFrame({"mse": xgbr_mse,"mae": xgbr_mae,"rmse": xgbr_rmse,  "r2": xgbr_r2, "deviation": deviation_function(y_val, xgbr_pred)},index=['XGBoost Regression'])

# %%
Axis = [y_val.mean()] * len(y_val)
plt.figure(figsize=(16, 9))
plt.ylabel('XGBoost Regression Result')
plt.plot(y_val, 'blue', label='Actual data')
plt.plot(Axis, color="black")
plt.plot(xgbr_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Comparision

# %% [markdown]
# https://stats.stackexchange.com/questions/183265/what-does-negative-r-squared-mean#:~:text=It%20means%20you've%20done,least%20squares%20regression%20line%20itself.

# %% [markdown]
# https://www.kaggle.com/questions-and-answers/267943

# %%
df_evaluation = pd.concat([lr_df, svr_df, dtr_df, rfr_df, xgbr_df]) 
df_evaluation
# Out:
#                                   mse        mae       rmse        r2  \
# Linear Regression          333.886574  13.991826  18.272563  0.327839
# Support Vector Regression  551.118317  18.478895  23.475909 -5.853417
# Decision Tree Regression   753.956820  20.606230  27.458274  0.157881
# Random Forest Regression   324.180913  13.689643  18.005025  0.273986
# XGBoost Regression         292.321678  13.147758  17.097417  0.456422
#
#                            deviation
# Linear Regression           0.080978
# Support Vector Regression   0.106958
# Decision Tree Regression    0.118546
# Random Forest Regression    0.079200
# XGBoost Regression          0.075626

# %%
df_evaluation.to_csv("/content/drive/My Drive/DataMining/POC/LungCancer/Evaluation/Raw/basic.csv")

# %% [markdown]
# # Save Model

# %%
import pickle
lr_filename = '/content/drive/My Drive/DataMining/POC/LungCancer/Model/Raw/lr_Baseline.h5'
pickle.dump(lr_model, open(lr_filename, 'wb'))
svr_filename = '/content/drive/My Drive/DataMining/POC/LungCancer/Model/Raw/svr_Baseline.h5'
pickle.dump(svr_model, open(svr_filename, 'wb'))
rfr_filename = '/content/drive/My Drive/DataMining/POC/LungCancer/Model/Raw/rfr_Baseline.h5'
pickle.dump(rfr_model, open(rfr_filename, 'wb'))
dtr_filename = '/content/drive/My Drive/DataMining/POC/LungCancer/Model/Raw/dtr_Baseline.h5'
pickle.dump(dtr_model, open(dtr_filename, 'wb'))
xgbr_filename = '/content/drive/My Drive/DataMining/POC/LungCancer/Model/Raw/xgbr_Baseline.h5'
pickle.dump(xgbr_model, open(xgbr_filename, 'wb'))
